# %% [markdown]
# #### 3. Build a deep feed-forward Artificial Neural Network by implementig the back propagation algorithm and test the same using appropriate datasets. Use the number of hidden layers greater than or equal to 4.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Input
import numpy as np
#from tensorflow.keras.datasets import mnist

# Load and preprocess MNIST dataset
data_mnist = np.load('mnist.npz')
x_train, y_train = data_mnist['x_train'], data_mnist['y_train']
x_test, y_test = data_mnist['x_test'], data_mnist['y_test']

x_train, x_test = x_train / 255.0, x_test / 255.0  # Normalize inputs to [0, 1]

# Define the model
model = Sequential([
    Input(shape=(28, 28)),  # Define the input shape explicitly using Input layer
    Flatten(),  # Flatten 28x28 images into a vector
    Dense(128, activation='relu'),  # First hidden layer
    Dense(128, activation='relu'),  # Second hidden layer
    Dense(64, activation='relu'),   # Third hidden layer
    Dense(64, activation='relu'),   # Fourth hidden layer
    Dense(10, activation='softmax') # Output layer with 10 classes
])

# Compile and train the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.2)
print("\n Training complete! \n")
# Evaluate the model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# Epoch 1/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.8507 - loss: 0.4938 - val_accuracy: 0.9602 - val_loss: 0.1387
# Epoch 2/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9634 - loss: 0.1165 - val_accuracy: 0.9664 - val_loss: 0.1099
# Epoch 3/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9767 - loss: 0.0751 - val_accuracy: 0.9661 - val_loss: 0.1166
# Epoch 4/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9805 - loss: 0.0605 - val_accuracy: 0.9708 - val_loss: 0.0962
# Epoch 5/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9842 - loss: 0.0485 - val_accuracy: 0.9737 - val_loss: 0.0893
# Epoch 6/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9871 - loss: 0.0402 - val_accuracy: 0.9717 - val_loss: 0.1042
# Epoch 7/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9889 - loss: 0.0329 - val_accuracy: 0.9688 - val_loss: 0.1070
# Epoch 8/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9915 - loss: 0.0260 - val_accuracy: 0.9723 - val_loss: 0.1019
# Epoch 9/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9917 - loss: 0.0258 - val_accuracy: 0.9762 - val_loss: 0.0948
# Epoch 10/10
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9914 - loss: 0.0250 - val_accuracy: 0.9769 - val_loss: 0.1029
#
#  Training complete!
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9755 - loss: 0.1140
# Test Loss: 0.0909
# Test Accuracy: 0.9799
